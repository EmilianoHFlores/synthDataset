# %%
import os
import random
import json
import numpy as np
import cv2
from PIL import Image, ImageDraw, ImageEnhance, ImageFilter
from pycocotools import mask
from skimage import measure
import json
import open3d as o3d
import yaml

# %%
# Define the paths to the three folders containing the images
datasetPath = "images_croped"
fg_folders = [
    (f"{datasetPath}/CocaCola/","cocacola" ),
    (f"{datasetPath}/Pringles/","pringles" ),
    (f"{datasetPath}/Zucaritas/","zucaritas" ),
    (f"{datasetPath}/Lysol/","lysol" ),
    (f"{datasetPath}/Destop/","destop" )
]
bg_folder = "backgrounds_resized/"
output_folder = "yolodataset/"

# %%
objects_list = ["cocacola", "pringles", "zucaritas", "lysol", "destop"]
annotations_ID = {}
categories = []
for i, object in enumerate(objects_list):
    annotations_ID[object] = i
    categories.append({"id": i, "name": object})

print(annotations_ID)
print(categories)
# Out:
# {'cocacola': 0, 'pringles': 1, 'zucaritas': 2, 'lysol': 3, 'destop': 4}
# [{'id': 0, 'name': 'cocacola'}, {'id': 1, 'name': 'pringles'}, {'id': 2, 'name': 'zucaritas'}, {'id': 3, 'name': 'lysol'}, {'id': 4, 'name': 'destop'}]

# %%
# Load the list of files in each of the three folders
fg_files = {}
for folder, category in fg_folders:
    fg_files[category] = os.listdir(folder)

# %%
os.mkdir(output_folder)
trainfolder = output_folder + "train/"
testfolder = output_folder + "test/"
validfolder = output_folder + "valid/"
os.mkdir(trainfolder)
os.mkdir(testfolder)
os.mkdir(validfolder)
os.mkdir(trainfolder + "images/")
os.mkdir(trainfolder + "labels/")
os.mkdir(testfolder + "images/")
os.mkdir(testfolder + "labels/")
os.mkdir(validfolder + "images/")
os.mkdir(validfolder + "labels/")

# %%
images=[]
annotations=[]
annotations2=[]

img_id=int(0)
anno_id=int(0)

rescaling_min = 0.1
rescaling_max = 0.5

# Ratios at which these values will be modified
brightness_ratio = 0.05
saturation_ratio = 0.05
hue_ratio = 0.02

for j in range(100):
    #create empty label file
    with open(f'{trainfolder}labels/{img_id}.txt', 'w') as file:
        pass
    #select hramdomly how many objects will be in an image
    num_objects = random.randint(0, 5)
    print("number of objects",num_objects)
    # Select random foreground images from the three folders, with replacement
    fg_categories = random.choices(objects_list, k=num_objects)
    
    fg_files_selected = []
    for category in fg_categories:
        fg_files_selected.append([category,random.choice(fg_files[category])])
    print("seleccion",fg_files_selected)
    # Load the selected foreground images using Pillow
    fg_imgs = []
    for img in fg_files_selected:
        folder = [f[0] for f in fg_folders if f[1] == img[0]][0]
        fg_imgs.append([img[0],Image.open(folder + img[1]),folder+img[1]])

    # Randomly resize and rotate the foreground images using Pillow's transform module
    # img[0] is category, img[1] is image, img[2] is path
    for img in fg_imgs:
        fg_img=img[1]
        angle = random.randint(-5, 5)
        scale = random.uniform(rescaling_min, rescaling_max)
        fg_img = fg_img.rotate(angle, resample=Image.BICUBIC, expand=True)
        fg_img = fg_img.resize((int(fg_img.width * scale), int(fg_img.height * scale)))
        fg_img = ImageEnhance.Brightness(fg_img).enhance(random.uniform(1.0, 1.5))
        fg_img = ImageEnhance.Contrast(fg_img).enhance(random.uniform(0.9, 1.1))
        fg_img = ImageEnhance.Color(fg_img).enhance(random.uniform(0.7, 1.3))
        fg_img = fg_img.filter(ImageFilter.GaussianBlur(radius=random.uniform(0.0, 0.5)))


        img[1] = fg_img

    # Load the background image using Pillow
    bg_files = os.listdir(bg_folder)
    bg_file = random.choice(bg_files)
    bg_img = Image.open(bg_folder + bg_file)

    # Define the maximum overlap as a percentage
    max_overlap_pct = 10

    # Define an array to keep track of occupied areas
    occupied = np.zeros((bg_img.height, bg_img.width))

    for img in fg_imgs:
        fg_img=img[1]

        # Calculate the maximum overlap area
        max_overlap_area = (fg_img.width * fg_img.height)

        seg_img = img[1]


        # Convert the image to a NumPy array
        img_arr = np.array(seg_img)
        # Create a binary mask of the non-transparent pixels
        mask = img_arr[:, :, 3] != 0

        # Convert the mask to a COCO format segmentation
        segmentation = []
        for i in range(mask.shape[0]):
            for j in range(mask.shape[1]):
                if mask[i, j]:
                    segmentation.append(j)
                    segmentation.append(i)
        segmentation = [segmentation]

        # Calculate the area of the segmentation
        area = 0
        for i in range(len(segmentation[0]) // 2):
            x1 = segmentation[0][2 * i]
            y1 = segmentation[0][2 * i + 1]
            x2 = segmentation[0][(2 * i + 2) % len(segmentation[0])]
            y2 = segmentation[0][(2 * i + 3) % len(segmentation[0])]
            area += x1 * y2 - x2 * y1
        area = abs(area) / 2
        
        # Draw the segmentation onto a copy of the original image
        #image_copy = image.copy()
        #cv2.fillPoly(image_copy, aux_segmentation, color=(0, 255, 0))

        # Display the image with segmentation overlay
        #cv2.imshow('Image with Segmentation', image_copy)
        #cv2.waitKey(0)
        #cv2.destroyAllWindows()

        # Calculate the maximum allowed position for the top-left corner
        max_x = bg_img.width - fg_img.width
        max_y = bg_img.height - fg_img.height
        area = fg_img.width * fg_img.height

        # Generate a random location until an unoccupied area is found that meets the overlap limit
        total_area = bg_img.width * bg_img.height
        overlap_area = total_area
        
        while overlap_area / area > max_overlap_pct / 100:
            x = random.randint(0, max_x)
            y = random.randint(0, max_y)

            # Calculate the overlap area
            overlap_area = np.sum(occupied[y:y+fg_img.height, x:x+fg_img.width])

            # Check if the area is unoccupied and the overlap limit is not exceeded
            if (max_overlap_area) >= overlap_area/10:
                break
            if i==10:
                continue
        
        for i in range(0, len(segmentation[0])):
            if i % 2:
                segmentation[0][i]=int(segmentation[0][i]+y)
            else :
                segmentation[0][i]=int(segmentation[0][i]+x)
        # Update the occupied array
        occupied[y:y+fg_img.height, x:x+fg_img.width] = 1

        bg_img.paste(fg_img, (x, y), fg_img)
        x_center_ann = (x+fg_img.width/2) / bg_img.width
        y_center_ann = (y+fg_img.height/2) / bg_img.height
        width_ann = fg_img.width / bg_img.width
        height_ann = fg_img.height / bg_img.height
        with open(f'{trainfolder}labels/{img_id}.txt', 'a') as f:
            f.write(f"{annotations_ID[img[0]]} {x_center_ann} {y_center_ann} {width_ann} {height_ann}\n")
        annotations.append({"id": anno_id,"image_id": img_id,"category_id": annotations_ID[img[0]],"bbox": [x, y, fg_img.width, fg_img.height],"segmentation": [],"area": fg_img.height*fg_img.width,"iscrowd": 0})
        anno_id=anno_id+1
        #draw = ImageDraw.Draw(bg_img)
        #fdraw.rectangle((x, y, x+fg_img.width, y+fg_img.height), outline='red', width=3)
    bg_img.save(f"{trainfolder}images/"+str(img_id)+".jpg", quality=100)
    images.append({"id": img_id, "file_name": str(img_id)+".jpg","height": bg_img.height,"width": bg_img.width})
    img_id=img_id+1

#making data.yaml
data = dict(
    train = f"{trainfolder}images",
    val = f"{validfolder}images",
    test = f"{validfolder}images",
    nc = len(annotations_ID),
    names = list(annotations_ID.keys())
    )
#storing
with open(f'{output_folder}data.yaml', 'w') as outfile:
    yaml.dump(data, outfile, default_flow_style=False)
# Out:
# number of objects 4
# seleccion [['cocacola', 'coca_19.png'], ['pringles', 'image_0033.png'], ['lysol', 'lysol_36.png'], ['pringles', 'image_0013.png']]
# number of objects 5
# seleccion [['lysol', 'lysol_153.png'], ['zucaritas', 'image_0069.png'], ['lysol', 'lysol_72.png'], ['destop', 'destop_168.png'], ['zucaritas', 'image_0030.png']]
# number of objects 5
# seleccion [['zucaritas', 'image_0018.png'], ['lysol', 'lysol_39.png'], ['cocacola', 'coca_26.png'], ['pringles', 'image2.0_0027.png'], ['cocacola', 'coca_90.png']]
# number of objects 5
# seleccion [['pringles', 'image_0000.png'], ['pringles', 'image2.0_0003.png'], ['cocacola', 'coca_55.png'], ['lysol', 'lysol_183.png'], ['lysol', 'lysol_189.png']]
# number of objects 0
# seleccion []
# number of objects 5
# seleccion [['lysol', 'lysol_95.png'], ['zucaritas', 'image_0015.png'], ['cocacola', 'coca_33.png'], ['pringles', 'image_0041.png'], ['cocacola', 'coca_96.png']]
# number of objects 4
# seleccion [['pringles', 'image2.0_0039.png'], ['pringles', 'image_0015.png'], ['pringles', 'image_0021.png'], ['zucaritas', 'image_0007.png']]
# number of objects 3
# seleccion [['destop', 'destop_99.png'], ['zucaritas', 'image_0066.png'], ['pringles', 'image2.0_0037.png']]
# number of objects 5
# seleccion [['cocacola', 'coca_63.png'], ['pringles', 'image_0000.png'], ['destop', 'destop_133.png'], ['cocacola', 'coca_16.png'], ['zucaritas', 'image_0074.png']]
# number of objects 0
# seleccion []
# number of objects 1
# seleccion [['pringles', 'image2.0_0010.png']]
# number of objects 0
# seleccion []
# number of objects 5
# seleccion [['destop', 'destop_32.png'], ['lysol', 'lysol_158.png'], ['pringles', 'image_0049.png'], ['lysol', 'lysol_27.png'], ['pringles', 'image_0011.png']]
# number of objects 0
# seleccion []
# number of objects 5
# seleccion [['pringles', 'image_0002.png'], ['cocacola', 'coca_10.png'], ['destop', 'destop_81.png'], ['cocacola', 'coca_62.png'], ['destop', 'destop_38.png']]
# number of objects 5
# seleccion [['destop', 'destop_50.png'], ['pringles', 'image_0019.png'], ['pringles', 'image2.0_0045.png'], ['cocacola', 'coca_33.png'], ['lysol', 'lysol_100.png']]
# number of objects 0
# seleccion []
# number of objects 2
# seleccion [['lysol', 'lysol_79.png'], ['cocacola', 'coca_67.png']]
# number of objects 0
# seleccion []
# number of objects 4
# seleccion [['pringles', 'image2.0_0036.png'], ['zucaritas', 'image_0039.png'], ['zucaritas', 'image_0012.png'], ['pringles', 'image2.0_0021.png']]
# number of objects 5
# seleccion [['destop', 'destop_140.png'], ['destop', 'destop_62.png'], ['destop', 'destop_114.png'], ['destop', 'destop_84.png'], ['destop', 'destop_107.png']]
# number of objects 4
# seleccion [['destop', 'destop_20.png'], ['zucaritas', 'image_0031.png'], ['zucaritas', 'image_0073.png'], ['pringles', 'image2.0_0004.png']]
# number of objects 3
# seleccion [['destop', 'destop_17.png'], ['cocacola', 'coca_65.png'], ['pringles', 'image_0023.png']]
# number of objects 3
# seleccion [['lysol', 'lysol_121.png'], ['zucaritas', 'image_0016.png'], ['pringles', 'image2.0_0017.png']]
# number of objects 3
# seleccion [['pringles', 'image_0017.png'], ['pringles', 'image_0016.png'], ['pringles', 'image2.0_0029.png']]
# number of objects 1
# seleccion [['lysol', 'lysol_197.png']]
# number of objects 0
# seleccion []
# number of objects 5
# seleccion [['pringles', 'image_0000.png'], ['cocacola', 'coca_51.png'], ['zucaritas', 'image_0015.png'], ['lysol', 'lysol_19.png'], ['destop', 'destop_103.png']]
# number of objects 1
# seleccion [['destop', 'destop_121.png']]
# number of objects 1
# seleccion [['cocacola', 'coca_16.png']]
# number of objects 0
# seleccion []
# number of objects 2
# seleccion [['destop', 'destop_121.png'], ['lysol', 'lysol_131.png']]
# number of objects 3
# seleccion [['cocacola', 'coca_16.png'], ['zucaritas', 'image_0086.png'], ['pringles', 'image_0041.png']]
# number of objects 1
# seleccion [['pringles', 'image2.0_0026.png']]
# number of objects 3
# seleccion [['pringles', 'image2.0_0024.png'], ['lysol', 'lysol_38.png'], ['pringles', 'image2.0_0048.png']]
# number of objects 3
# seleccion [['destop', 'destop_170.png'], ['pringles', 'image2.0_0012.png'], ['destop', 'destop_17.png']]
# number of objects 5
# seleccion [['zucaritas', 'image_0083.png'], ['destop', 'destop_145.png'], ['zucaritas', 'image_0068.png'], ['destop', 'destop_38.png'], ['zucaritas', 'image_0080.png']]
# number of objects 5
# seleccion [['lysol', 'lysol_22.png'], ['pringles', 'image2.0_0002.png'], ['cocacola', 'coca_61.png'], ['pringles', 'image_0031.png'], ['zucaritas', 'image_0026.png']]
# number of objects 2
# seleccion [['cocacola', 'coca_74.png'], ['lysol', 'lysol_180.png']]
# number of objects 4
# seleccion [['destop', 'destop_30.png'], ['pringles', 'image_0009.png'], ['destop', 'destop_38.png'], ['destop', 'destop_19.png']]
# number of objects 4
# seleccion [['lysol', 'lysol_31.png'], ['pringles', 'image2.0_0020.png'], ['lysol', 'lysol_112.png'], ['cocacola', 'coca_36.png']]
# number of objects 3
# seleccion [['destop', 'destop_162.png'], ['destop', 'destop_83.png'], ['lysol', 'lysol_122.png']]
# number of objects 0
# seleccion []
# number of objects 3
# seleccion [['lysol', 'lysol_78.png'], ['cocacola', 'coca_82.png'], ['pringles', 'image_0049.png']]
# number of objects 2
# seleccion [['destop', 'destop_69.png'], ['lysol', 'lysol_163.png']]
# number of objects 2
# seleccion [['zucaritas', 'image_0019.png'], ['pringles', 'image_0030.png']]
# number of objects 4
# seleccion [['lysol', 'lysol_93.png'], ['destop', 'destop_9.png'], ['pringles', 'image2.0_0014.png'], ['zucaritas', 'image_0002.png']]
# number of objects 5
# seleccion [['destop', 'destop_13.png'], ['lysol', 'lysol_4.png'], ['zucaritas', 'image_0080.png'], ['lysol', 'lysol_159.png'], ['lysol', 'lysol_100.png']]
# number of objects 2
# seleccion [['zucaritas', 'image_0035.png'], ['cocacola', 'coca_82.png']]
# number of objects 3
# seleccion [['cocacola', 'coca_20.png'], ['destop', 'destop_108.png'], ['zucaritas', 'image_0020.png']]
# number of objects 2
# seleccion [['lysol', 'lysol_49.png'], ['cocacola', 'coca_20.png']]
# number of objects 5
# seleccion [['pringles', 'image2.0_0046.png'], ['lysol', 'lysol_25.png'], ['zucaritas', 'image_0042.png'], ['pringles', 'image2.0_0004.png'], ['lysol', 'lysol_122.png']]
# number of objects 1
# seleccion [['zucaritas', 'image_0078.png']]
# number of objects 3
# seleccion [['destop', 'destop_47.png'], ['zucaritas', 'image_0021.png'], ['destop', 'destop_157.png']]
# number of objects 3
# seleccion [['destop', 'destop_114.png'], ['zucaritas', 'image_0008.png'], ['pringles', 'image_0042.png']]
# number of objects 2
# seleccion [['destop', 'destop_68.png'], ['lysol', 'lysol_12.png']]
# number of objects 0
# seleccion []
# number of objects 5
# seleccion [['cocacola', 'coca_20.png'], ['pringles', 'image_0030.png'], ['zucaritas', 'image_0041.png'], ['pringles', 'image_0012.png'], ['destop', 'destop_136.png']]
# number of objects 0
# seleccion []
# number of objects 0
# seleccion []
# number of objects 0
# seleccion []
# number of objects 4
# seleccion [['cocacola', 'coca_45.png'], ['pringles', 'image2.0_0001.png'], ['pringles', 'image2.0_0026.png'], ['lysol', 'lysol_188.png']]
# number of objects 0
# seleccion []
# number of objects 5
# seleccion [['zucaritas', 'image_0065.png'], ['cocacola', 'coca_18.png'], ['lysol', 'lysol_9.png'], ['pringles', 'image2.0_0017.png'], ['lysol', 'lysol_189.png']]
# number of objects 4
# seleccion [['cocacola', 'coca_9.png'], ['lysol', 'lysol_61.png'], ['cocacola', 'coca_31.png'], ['lysol', 'lysol_90.png']]
# number of objects 4
# seleccion [['zucaritas', 'image_0079.png'], ['pringles', 'image2.0_0042.png'], ['lysol', 'lysol_162.png'], ['lysol', 'lysol_34.png']]
# number of objects 1
# seleccion [['pringles', 'image_0033.png']]
# number of objects 5
# seleccion [['lysol', 'lysol_37.png'], ['cocacola', 'coca_81.png'], ['cocacola', 'coca_63.png'], ['pringles', 'image_0030.png'], ['pringles', 'image_0037.png']]
# number of objects 4
# seleccion [['cocacola', 'coca_41.png'], ['lysol', 'lysol_69.png'], ['pringles', 'image_0031.png'], ['zucaritas', 'image_0051.png']]
# number of objects 3
# seleccion [['lysol', 'lysol_114.png'], ['destop', 'destop_80.png'], ['destop', 'destop_64.png']]
# number of objects 1
# seleccion [['zucaritas', 'image_0075.png']]
# number of objects 2
# seleccion [['lysol', 'lysol_85.png'], ['destop', 'destop_91.png']]
# number of objects 1
# seleccion [['destop', 'destop_103.png']]
# number of objects 4
# seleccion [['zucaritas', 'image_0078.png'], ['destop', 'destop_93.png'], ['pringles', 'image2.0_0009.png'], ['destop', 'destop_76.png']]
# number of objects 5
# seleccion [['destop', 'destop_72.png'], ['pringles', 'image_0027.png'], ['destop', 'destop_33.png'], ['pringles', 'image_0014.png'], ['cocacola', 'coca_34.png']]
# number of objects 0
# seleccion []
# number of objects 0
# seleccion []
# number of objects 3
# seleccion [['destop', 'destop_163.png'], ['pringles', 'image_0025.png'], ['lysol', 'lysol_147.png']]
# number of objects 3
# seleccion [['zucaritas', 'image_0038.png'], ['cocacola', 'coca_8.png'], ['lysol', 'lysol_184.png']]
# number of objects 2
# seleccion [['lysol', 'lysol_117.png'], ['cocacola', 'coca_46.png']]
# number of objects 1
# seleccion [['cocacola', 'coca_26.png']]
# number of objects 1
# seleccion [['pringles', 'image2.0_0008.png']]
# number of objects 0
# seleccion []
# number of objects 2
# seleccion [['destop', 'destop_132.png'], ['lysol', 'lysol_153.png']]
# number of objects 4
# seleccion [['pringles', 'image_0029.png'], ['lysol', 'lysol_17.png'], ['lysol', 'lysol_148.png'], ['pringles', 'image2.0_0040.png']]
# number of objects 3
# seleccion [['pringles', 'image2.0_0040.png'], ['lysol', 'lysol_67.png'], ['zucaritas', 'image_0088.png']]
# number of objects 4
# seleccion [['cocacola', 'coca_44.png'], ['zucaritas', 'image_0024.png'], ['zucaritas', 'image_0041.png'], ['destop', 'destop_78.png']]
# number of objects 3
# seleccion [['lysol', 'lysol_44.png'], ['pringles', 'image2.0_0028.png'], ['zucaritas', 'image_0016.png']]
# number of objects 3
# seleccion [['pringles', 'image2.0_0022.png'], ['pringles', 'image_0014.png'], ['pringles', 'image_0012.png']]
# number of objects 2
# seleccion [['zucaritas', 'image_0068.png'], ['pringles', 'image2.0_0049.png']]
# number of objects 0
# seleccion []
# number of objects 4
# seleccion [['zucaritas', 'image_0076.png'], ['zucaritas', 'image_0025.png'], ['cocacola', 'coca_36.png'], ['zucaritas', 'image_0007.png']]
# number of objects 4
# seleccion [['destop', 'destop_153.png'], ['cocacola', 'coca_77.png'], ['destop', 'destop_8.png'], ['destop', 'destop_95.png']]
# number of objects 1
# seleccion [['destop', 'destop_127.png']]
# number of objects 5
# seleccion [['pringles', 'image_0039.png'], ['pringles', 'image2.0_0026.png'], ['lysol', 'lysol_184.png'], ['pringles', 'image_0036.png'], ['pringles', 'image_0010.png']]
# number of objects 1
# seleccion [['zucaritas', 'image_0099.png']]
# number of objects 4
# seleccion [['destop', 'destop_108.png'], ['pringles', 'image2.0_0015.png'], ['zucaritas', 'image_0013.png'], ['pringles', 'image2.0_0029.png']]
# number of objects 0
# seleccion []
# number of objects 5
# seleccion [['pringles', 'image2.0_0036.png'], ['lysol', 'lysol_91.png'], ['destop', 'destop_137.png'], ['zucaritas', 'image_0084.png'], ['destop', 'destop_77.png']]
# number of objects 5
# seleccion [['cocacola', 'coca_15.png'], ['zucaritas', 'image_0059.png'], ['destop', 'destop_2.png'], ['pringles', 'image2.0_0033.png'], ['destop', 'destop_104.png']]

# %%
# Define the COCO dictionary
coco_dict = {
    "images": images,
    "annotations": annotations,
    "categories": categories
}

# %%
coco_dict2 = {
    "images": images,
    "annotations": annotations2,
    "categories": categories
}

# %%
coco_dict2
# Convert the dictionary to a JSON string
json_string = json.dumps(coco_dict2)

# Write the JSON string to a file
with open("annotations_val_seg.json", 'w') as f:
    f.write(json_string)

# %%
coco_dict
# Convert the dictionary to a JSON string
json_string = json.dumps(coco_dict)

# Write the JSON string to a file
with open("annotations_val.json", 'w') as f:
    f.write(json_string)
